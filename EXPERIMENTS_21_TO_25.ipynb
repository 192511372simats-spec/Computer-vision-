# %%
# Import required libraries
import cv2
import numpy as np
from google.colab import files
from google.colab.patches import cv2_imshow

# Upload image
uploaded = files.upload()

# Get uploaded image name
image_name = list(uploaded.keys())[0]

# Read the original image
img = cv2.imread(image_name)

# Check if image is loaded
if img is None:
    print("Error: Unable to load image.")
else:
    # Laplacian mask with diagonal neighbors
    kernel = np.array([[1, 1, 1],
                       [1, -8, 1],
                       [1, 1, 1]], dtype=np.float32)

    # Apply Laplacian filter
    laplacian = cv2.filter2D(img, cv2.CV_32F, kernel)

    # Convert Laplacian to 8-bit
    laplacian = cv2.convertScaleAbs(laplacian)

    # Sharpen the image
    sharpened = cv2.subtract(img, laplacian)

    # Display original image
    print("Original Image")
    cv2_imshow(img)

    # Display sharpened image
    print("Sharpened Image")
    cv2_imshow(sharpened)

    # Save the output image
    cv2.imwrite("Sharpened_Image_Diagonal.jpg", sharpened)

    print("Image sharpening completed successfully!")
# Out:
#      <input type="file" id="files-e887f9a6-0a61-4b4e-8ed3-46dd30a51d80" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e887f9a6-0a61-4b4e-8ed3-46dd30a51d80">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Import required libraries
import cv2
import numpy as np
from google.colab import files
from google.colab.patches import cv2_imshow

# Upload image
uploaded = files.upload()

# Get uploaded image name
image_name = list(uploaded.keys())[0]

# Read the original image
image = cv2.imread(image_name)

# Check if image is loaded
if image is None:
    print("Error: Unable to load image.")
else:
    # Laplacian mask with positive center coefficient
    kernel = np.array([[0, -1, 0],
                       [-1, 4, -1],
                       [0, -1, 0]], dtype=np.float32)

    # Apply Laplacian filter
    laplacian = cv2.filter2D(image, cv2.CV_32F, kernel)

    # Convert to 8-bit image
    laplacian = cv2.convertScaleAbs(laplacian)

    # Sharpen the image
    sharpened = cv2.add(image, laplacian)

    # Display original image
    print("Original Image")
    cv2_imshow(image)

    # Display sharpened image
    print("Sharpened Image")
    cv2_imshow(sharpened)

    # Save output image
    cv2.imwrite("Sharpened_Image_Positive_Center.jpg", sharpened)

    print("Image sharpening completed successfully!")
# Out:
#      <input type="file" id="files-7b90d4aa-8497-437d-9ef2-dacb7e7b459d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7b90d4aa-8497-437d-9ef2-dacb7e7b459d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Perform Sharpening of Image using Unsharp Masking

from PIL import Image, ImageFilter
from google.colab import files
import matplotlib.pyplot as plt

# Upload the image
uploaded = files.upload()

# Get uploaded image name
image_name = list(uploaded.keys())[0]

# Read the original image
original_image = Image.open(image_name)

# Perform Sharpening using Unsharp Masking
sharpened_image = original_image.filter(
    ImageFilter.UnsharpMask(
        radius=3,
        percent=200,
        threshold=5
    )
)

# Display Original Image
plt.figure(figsize=(6,6))
plt.title("Original Image")
plt.imshow(original_image)
plt.axis("off")
plt.show()

# Display Sharpened Image using Unsharp Masking
plt.figure(figsize=(6,6))
plt.title("Sharpening Image using Unsharp Masking")
plt.imshow(sharpened_image)
plt.axis("off")
plt.show()

# Convert RGBA to RGB (if needed) and save
if sharpened_image.mode == "RGBA":
    sharpened_image = sharpened_image.convert("RGB")

sharpened_image.save("Sharpening_Image_Using_Unsharp_Masking.jpg")

print("Sharpening Image using Unsharp Masking completed successfully.")
# Out:
#      <input type="file" id="files-75f5c40c-ae9d-4593-b12e-7c35cfe78a80" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-75f5c40c-ae9d-4593-b12e-7c35cfe78a80">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Import required libraries
import cv2
import numpy as np
from google.colab import files
from google.colab.patches import cv2_imshow

# Upload image
uploaded = files.upload()

# Get uploaded image name
image_name = list(uploaded.keys())[0]

# Read the original image
image = cv2.imread(image_name)

# Check if image is loaded
if image is None:
    print("Error: Unable to load image.")
else:

    # Function for High-Boost Sharpening
    def high_boost_filter(image, boost_factor):

        # Blur the image using a 3x3 averaging filter
        blur_image = cv2.blur(image, (3, 3))

        # Convert images to float
        image_float = image.astype(np.float32)
        blur_float = blur_image.astype(np.float32)

        # High-Boost Mask
        sharpened = image_float + (image_float - blur_float) * boost_factor

        # Clip values between 0 and 255
        sharpened = np.clip(sharpened, 0, 255).astype(np.uint8)

        return sharpened

    # Apply High-Boost Filter
    sharpened_image = high_boost_filter(image, 1.5)

    # Display Original Image
    print("Original Image")
    cv2_imshow(image)

    # Display Sharpened Image
    print("Sharpening Image using High-Boost Mask")
    cv2_imshow(sharpened_image)

    # Save Output Image
    cv2.imwrite("Sharpening_Image_Using_High_Boost_Mask.jpg", sharpened_image)

    print("Sharpening Image using High-Boost Mask completed successfully!")
# Out:
#      <input type="file" id="files-ea4f8a6c-4af7-447e-88ac-466b00799875" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ea4f8a6c-4af7-447e-88ac-466b00799875">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Import required libraries
import cv2
import numpy as np
from google.colab import files
from google.colab.patches import cv2_imshow

# Upload image
uploaded = files.upload()

# Get uploaded image name
image_name = list(uploaded.keys())[0]

# Read the original image
image = cv2.imread(image_name)

# Check if image is loaded
if image is None:
    print("Error: Unable to load image.")
else:
    # Convert image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Compute gradients along X and Y directions
    gradient_x = cv2.Sobel(gray, cv2.CV_64F, 1, 0, ksize=3)
    gradient_y = cv2.Sobel(gray, cv2.CV_64F, 0, 1, ksize=3)

    # Compute gradient magnitude
    gradient = cv2.magnitude(gradient_x, gradient_y)

    # Convert to 8-bit image
    gradient = cv2.convertScaleAbs(gradient)

    # Display Original Image
    print("Original Image")
    cv2_imshow(image)

    # Display Gradient Masking Image
    print("Sharpening Image using Gradient Masking")
    cv2_imshow(gradient)

    # Save the output image
    cv2.imwrite("Sharpening_Image_Using_Gradient_Masking.jpg", gradient)

    print("Sharpening Image using Gradient Masking completed successfully!")
# Out:
#      <input type="file" id="files-2b7a5dce-bb8f-4f9d-b866-6073bb1f00cb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2b7a5dce-bb8f-4f9d-b866-6073bb1f00cb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
