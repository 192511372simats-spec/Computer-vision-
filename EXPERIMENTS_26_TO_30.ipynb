# %%
import cv2
from google.colab import files
from google.colab.patches import cv2_imshow

# Upload logo image
print("Upload Logo Image")
uploaded_logo = files.upload()
logo_name = list(uploaded_logo.keys())[0]
logo = cv2.imread(logo_name)

# Upload background image
print("Upload Background Image")
uploaded_img = files.upload()
img_name = list(uploaded_img.keys())[0]
img = cv2.imread(img_name)

# Resize logo
logo = cv2.resize(logo, (150, 150))

h_logo, w_logo = logo.shape[:2]
h_img, w_img = img.shape[:2]

# Position at center
x = (w_img - w_logo) // 2
y = (h_img - h_logo) // 2

roi = img[y:y+h_logo, x:x+w_logo]

# Watermark
result = cv2.addWeighted(roi, 0.7, logo, 0.3, 0)

img[y:y+h_logo, x:x+w_logo] = result

print("Logo Image")
cv2_imshow(logo)

print("Original Image")
cv2_imshow(cv2.imread(img_name))

print("Watermarked Image")
cv2_imshow(img)

cv2.imwrite("Watermarked_Image.jpg", img)

print("Watermark inserted successfully!")
# Out:
# Upload Logo Image
#      <input type="file" id="files-400ac454-9b73-4da5-bd95-99b2c1bc465b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-400ac454-9b73-4da5-bd95-99b2c1bc465b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
import cv2
from google.colab import files
from google.colab.patches import cv2_imshow

# ---------------- Upload Background ----------------
print("Upload Background Image")
uploaded_bg = files.upload()

bg_name = list(uploaded_bg.keys())[0]
background = cv2.imread(bg_name)

# ---------------- Upload Object ----------------
print("Upload Object Image")
uploaded_obj = files.upload()

obj_name = list(uploaded_obj.keys())[0]
object_img = cv2.imread(obj_name)

# ---------------- Crop ----------------
crop = background[50:300, 50:300]

print("Cropped Image")
cv2_imshow(crop)

cv2.imwrite("Cropped_Image.jpg", crop)

# ---------------- Copy & Paste ----------------

# Resize object image
object_img = cv2.resize(object_img, (150,150))

rows, cols = object_img.shape[:2]

# Region of Interest
roi = background[50:50+rows, 50:50+cols]

# Create mask
gray = cv2.cvtColor(object_img, cv2.COLOR_BGR2GRAY)

_, mask = cv2.threshold(gray, 10, 255, cv2.THRESH_BINARY)

mask_inv = cv2.bitwise_not(mask)

background_part = cv2.bitwise_and(roi, roi, mask=mask_inv)

object_part = cv2.bitwise_and(object_img, object_img, mask=mask)

result = cv2.add(background_part, object_part)

background[50:50+rows, 50:50+cols] = result

print("Copy and Paste Image")
cv2_imshow(background)

cv2.imwrite("Copy_Paste_Image.jpg", background)

print("Cropping, Copying and Pasting completed successfully!")
# Out:
# Upload Background Image
#      <input type="file" id="files-0402ce0e-87e6-4062-9b21-7293a9bc4a4e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0402ce0e-87e6-4062-9b21-7293a9bc4a4e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
# Import required libraries
import cv2
import numpy as np
from google.colab import files
from google.colab.patches import cv2_imshow

# Upload image
uploaded = files.upload()

# Get uploaded image name
image_name = list(uploaded.keys())[0]

# Read the image
img = cv2.imread(image_name)

# Check if image is loaded
if img is None:
    print("Error: Unable to load image.")
else:
    # Convolution Kernel
    kernel = np.array([[-1, -1, -1],
                       [-1,  9, -1],
                       [-1, -1, -1]])

    # Apply Convolution
    convolution_img = cv2.filter2D(img, -1, kernel)

    # Display Original Image
    print("Input Image")
    cv2_imshow(img)

    # Display Convolution Result
    print("Boundary Image using Convolution Kernel")
    cv2_imshow(convolution_img)

    # Save Output Image
    cv2.imwrite("Boundary_Convolution_Image.jpg", convolution_img)

    print("Boundary detection using Convolution Kernel completed successfully!")
# Out:
#      <input type="file" id="files-fa512509-f865-48b1-979a-57f365432c1c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fa512509-f865-48b1-979a-57f365432c1c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import cv2
import numpy as np
from google.colab import files
from google.colab.patches import cv2_imshow

# Upload Image
print("Upload Input Image")
uploaded = files.upload()

image_name = list(uploaded.keys())[0]

# Read original image in color
original = cv2.imread(image_name)

# Convert to grayscale for erosion
gray = cv2.cvtColor(original, cv2.COLOR_BGR2GRAY)

# Create kernel
kernel = np.ones((5,5), np.uint8)

# Perform erosion
eroded = cv2.erode(gray, kernel, iterations=1)

# Display Original Color Image
print("Original Image")
cv2_imshow(original)

# Display Eroded Image
print("Eroded Image")
cv2_imshow(eroded)

# Save output
cv2.imwrite("Eroded_Image.jpg", eroded)

print("Morphological operation using Erosion completed successfully!")
# Out:
# Upload Input Image
#      <input type="file" id="files-cad36ecf-eb7c-411c-80a1-9b9b9fe44b82" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cad36ecf-eb7c-411c-80a1-9b9b9fe44b82">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
import cv2
import numpy as np
from google.colab import files
from google.colab.patches import cv2_imshow

# Upload Image
print("Upload Input Image")
uploaded = files.upload()

image_name = list(uploaded.keys())[0]

# Read the image in color
img = cv2.imread(image_name)

# Create kernel
kernel = np.ones((5,5), np.uint8)

# Perform dilation directly on the color image
dilated = cv2.dilate(img, kernel, iterations=1)

# Display images
print("Original Image")
cv2_imshow(img)

print("Dilated Image")
cv2_imshow(dilated)

# Save output
cv2.imwrite("Dilated_Image.jpg", dilated)

print("Morphological operation using Dilation completed successfully!")
# Out:
# Upload Input Image
#      <input type="file" id="files-04a25ef7-b5eb-4972-95cf-14f894890a0a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-04a25ef7-b5eb-4972-95cf-14f894890a0a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...
